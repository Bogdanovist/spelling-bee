# %%
from models import Base
from db.session import engine
import pandas as pd
from sqlalchemy import insert
from models import Word

def commit_sql(stmt):
    with engine.connect() as conn:
        ret = conn.execute(stmt)
        conn.commit()
    
    return ret

words = pd.read_csv('data/import_words.csv')

for indx, row in words.iterrows():
    stmt = (
            insert(Word).
            values(word=row.word,
                level = row.level).
            returning(Word.word)
        )
    try:
        word_id = commit_sql(stmt).first()[0]
        print(word_id)
    except Exception as e:
        continue
# Out:
# 2023-07-16 12:21:21,278 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,279 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,279 INFO sqlalchemy.engine.Engine [cached since 77.34s ago] {'word': 'abrasive', 'level': 3}
# 2023-07-16 12:21:21,280 INFO sqlalchemy.engine.Engine ROLLBACK
# 2023-07-16 12:21:21,282 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,283 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,283 INFO sqlalchemy.engine.Engine [cached since 77.35s ago] {'word': 'boundary', 'level': 3}
# 2023-07-16 12:21:21,284 INFO sqlalchemy.engine.Engine COMMIT
# boundary
# 2023-07-16 12:21:21,285 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,286 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,286 INFO sqlalchemy.engine.Engine [cached since 77.35s ago] {'word': 'disappointed', 'level': 3}
# 2023-07-16 12:21:21,287 INFO sqlalchemy.engine.Engine COMMIT
# disappointed
# 2023-07-16 12:21:21,289 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,293 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,295 INFO sqlalchemy.engine.Engine [cached since 77.36s ago] {'word': 'gazelle', 'level': 3}
# 2023-07-16 12:21:21,296 INFO sqlalchemy.engine.Engine COMMIT
# gazelle
# 2023-07-16 12:21:21,301 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,305 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,307 INFO sqlalchemy.engine.Engine [cached since 77.37s ago] {'word': 'obedient', 'level': 3}
# 2023-07-16 12:21:21,310 INFO sqlalchemy.engine.Engine COMMIT
# obedient
# 2023-07-16 12:21:21,317 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,318 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,318 INFO sqlalchemy.engine.Engine [cached since 77.38s ago] {'word': 'absentee', 'level': 3}
# 2023-07-16 12:21:21,319 INFO sqlalchemy.engine.Engine COMMIT
# absentee
# 2023-07-16 12:21:21,327 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,328 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,328 INFO sqlalchemy.engine.Engine [cached since 77.39s ago] {'word': 'braille', 'level': 3}
# 2023-07-16 12:21:21,330 INFO sqlalchemy.engine.Engine COMMIT
# braille
# 2023-07-16 12:21:21,332 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,333 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,334 INFO sqlalchemy.engine.Engine [cached since 77.4s ago] {'word': 'disapproval', 'level': 3}
# 2023-07-16 12:21:21,335 INFO sqlalchemy.engine.Engine COMMIT
# disapproval
# 2023-07-16 12:21:21,337 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,337 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,337 INFO sqlalchemy.engine.Engine [cached since 77.4s ago] {'word': 'geranium', 'level': 3}
# 2023-07-16 12:21:21,338 INFO sqlalchemy.engine.Engine COMMIT
# geranium
# 2023-07-16 12:21:21,340 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,341 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,343 INFO sqlalchemy.engine.Engine [cached since 77.41s ago] {'word': 'obstacle', 'level': 3}
# 2023-07-16 12:21:21,350 INFO sqlalchemy.engine.Engine COMMIT
# obstacle
# 2023-07-16 12:21:21,352 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,352 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,352 INFO sqlalchemy.engine.Engine [cached since 77.42s ago] {'word': 'absolve', 'level': 3}
# 2023-07-16 12:21:21,353 INFO sqlalchemy.engine.Engine COMMIT
# absolve
# 2023-07-16 12:21:21,356 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,357 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,358 INFO sqlalchemy.engine.Engine [cached since 77.42s ago] {'word': 'business', 'level': 3}
# 2023-07-16 12:21:21,361 INFO sqlalchemy.engine.Engine COMMIT
# business
# 2023-07-16 12:21:21,363 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,363 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,363 INFO sqlalchemy.engine.Engine [cached since 77.43s ago] {'word': 'discerning', 'level': 3}
# 2023-07-16 12:21:21,364 INFO sqlalchemy.engine.Engine COMMIT
# discerning
# 2023-07-16 12:21:21,367 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,367 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,367 INFO sqlalchemy.engine.Engine [cached since 77.43s ago] {'word': 'ghastly', 'level': 3}
# 2023-07-16 12:21:21,372 INFO sqlalchemy.engine.Engine COMMIT
# ghastly
# 2023-07-16 12:21:21,374 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,374 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,374 INFO sqlalchemy.engine.Engine [cached since 77.44s ago] {'word': 'opposite', 'level': 3}
# 2023-07-16 12:21:21,375 INFO sqlalchemy.engine.Engine COMMIT
# opposite
# 2023-07-16 12:21:21,377 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,378 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,379 INFO sqlalchemy.engine.Engine [cached since 77.44s ago] {'word': 'accomplished', 'level': 3}
# 2023-07-16 12:21:21,384 INFO sqlalchemy.engine.Engine COMMIT
# accomplished
# 2023-07-16 12:21:21,386 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,387 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,387 INFO sqlalchemy.engine.Engine [cached since 77.45s ago] {'word': 'cajole', 'level': 3}
# 2023-07-16 12:21:21,388 INFO sqlalchemy.engine.Engine COMMIT
# cajole
# 2023-07-16 12:21:21,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,394 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,394 INFO sqlalchemy.engine.Engine [cached since 77.46s ago] {'word': 'discontinue', 'level': 3}
# 2023-07-16 12:21:21,397 INFO sqlalchemy.engine.Engine COMMIT
# discontinue
# 2023-07-16 12:21:21,399 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,399 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,400 INFO sqlalchemy.engine.Engine [cached since 77.46s ago] {'word': 'gimmick', 'level': 3}
# 2023-07-16 12:21:21,401 INFO sqlalchemy.engine.Engine COMMIT
# gimmick
# 2023-07-16 12:21:21,403 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,404 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,406 INFO sqlalchemy.engine.Engine [cached since 77.47s ago] {'word': 'original', 'level': 3}
# 2023-07-16 12:21:21,443 INFO sqlalchemy.engine.Engine COMMIT
# original
# 2023-07-16 12:21:21,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,446 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,446 INFO sqlalchemy.engine.Engine [cached since 77.51s ago] {'word': 'acrid', 'level': 3}
# 2023-07-16 12:21:21,447 INFO sqlalchemy.engine.Engine COMMIT
# acrid
# 2023-07-16 12:21:21,448 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,449 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,450 INFO sqlalchemy.engine.Engine [cached since 77.51s ago] {'word': 'calamari', 'level': 3}
# 2023-07-16 12:21:21,461 INFO sqlalchemy.engine.Engine COMMIT
# calamari
# 2023-07-16 12:21:21,464 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,464 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,464 INFO sqlalchemy.engine.Engine [cached since 77.53s ago] {'word': 'discordant', 'level': 3}
# 2023-07-16 12:21:21,465 INFO sqlalchemy.engine.Engine COMMIT
# discordant
# 2023-07-16 12:21:21,467 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,467 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,467 INFO sqlalchemy.engine.Engine [cached since 77.53s ago] {'word': 'hackneyed', 'level': 3}
# 2023-07-16 12:21:21,468 INFO sqlalchemy.engine.Engine COMMIT
# hackneyed
# 2023-07-16 12:21:21,470 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,470 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,471 INFO sqlalchemy.engine.Engine [cached since 77.54s ago] {'word': 'passionfruit', 'level': 3}
# 2023-07-16 12:21:21,474 INFO sqlalchemy.engine.Engine COMMIT
# passionfruit
# 2023-07-16 12:21:21,476 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,476 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,476 INFO sqlalchemy.engine.Engine [cached since 77.54s ago] {'word': 'adjust', 'level': 3}
# 2023-07-16 12:21:21,477 INFO sqlalchemy.engine.Engine COMMIT
# adjust
# 2023-07-16 12:21:21,478 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,479 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,479 INFO sqlalchemy.engine.Engine [cached since 77.54s ago] {'word': 'capacity', 'level': 3}
# 2023-07-16 12:21:21,480 INFO sqlalchemy.engine.Engine COMMIT
# capacity
# 2023-07-16 12:21:21,483 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,483 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,484 INFO sqlalchemy.engine.Engine [cached since 77.55s ago] {'word': 'dissuade', 'level': 3}
# 2023-07-16 12:21:21,485 INFO sqlalchemy.engine.Engine COMMIT
# dissuade
# 2023-07-16 12:21:21,487 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,487 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,487 INFO sqlalchemy.engine.Engine [cached since 77.55s ago] {'word': 'handkerchief', 'level': 3}
# 2023-07-16 12:21:21,488 INFO sqlalchemy.engine.Engine COMMIT
# handkerchief
# 2023-07-16 12:21:21,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,490 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,490 INFO sqlalchemy.engine.Engine [cached since 77.56s ago] {'word': 'pedestal', 'level': 3}
# 2023-07-16 12:21:21,491 INFO sqlalchemy.engine.Engine COMMIT
# pedestal
# 2023-07-16 12:21:21,499 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,501 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,501 INFO sqlalchemy.engine.Engine [cached since 77.57s ago] {'word': 'adornment', 'level': 3}
# 2023-07-16 12:21:21,533 INFO sqlalchemy.engine.Engine COMMIT
# adornment
# 2023-07-16 12:21:21,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,537 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,538 INFO sqlalchemy.engine.Engine [cached since 77.6s ago] {'word': 'carafe', 'level': 3}
# 2023-07-16 12:21:21,540 INFO sqlalchemy.engine.Engine COMMIT
# carafe
# 2023-07-16 12:21:21,541 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,541 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,542 INFO sqlalchemy.engine.Engine [cached since 77.61s ago] {'word': 'diversity', 'level': 3}
# 2023-07-16 12:21:21,548 INFO sqlalchemy.engine.Engine COMMIT
# diversity
# 2023-07-16 12:21:21,552 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,553 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,554 INFO sqlalchemy.engine.Engine [cached since 77.62s ago] {'word': 'heptathlon', 'level': 3}
# 2023-07-16 12:21:21,558 INFO sqlalchemy.engine.Engine COMMIT
# heptathlon
# 2023-07-16 12:21:21,560 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,560 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,561 INFO sqlalchemy.engine.Engine [cached since 77.63s ago] {'word': 'perilous', 'level': 3}
# 2023-07-16 12:21:21,562 INFO sqlalchemy.engine.Engine COMMIT
# perilous
# 2023-07-16 12:21:21,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,564 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,565 INFO sqlalchemy.engine.Engine [cached since 77.63s ago] {'word': 'affluent', 'level': 3}
# 2023-07-16 12:21:21,566 INFO sqlalchemy.engine.Engine COMMIT
# affluent
# 2023-07-16 12:21:21,568 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,569 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,569 INFO sqlalchemy.engine.Engine [cached since 77.63s ago] {'word': 'caramel', 'level': 3}
# 2023-07-16 12:21:21,570 INFO sqlalchemy.engine.Engine COMMIT
# caramel
# 2023-07-16 12:21:21,572 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,573 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,573 INFO sqlalchemy.engine.Engine [cached since 77.64s ago] {'word': 'dossier', 'level': 3}
# 2023-07-16 12:21:21,575 INFO sqlalchemy.engine.Engine COMMIT
# dossier
# 2023-07-16 12:21:21,577 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,578 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,579 INFO sqlalchemy.engine.Engine [cached since 77.64s ago] {'word': 'hostility', 'level': 3}
# 2023-07-16 12:21:21,580 INFO sqlalchemy.engine.Engine COMMIT
# hostility
# 2023-07-16 12:21:21,582 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,582 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,582 INFO sqlalchemy.engine.Engine [cached since 77.65s ago] {'word': 'priority', 'level': 3}
# 2023-07-16 12:21:21,583 INFO sqlalchemy.engine.Engine COMMIT
# priority
# 2023-07-16 12:21:21,586 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,586 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,586 INFO sqlalchemy.engine.Engine [cached since 77.65s ago] {'word': 'aggressive', 'level': 3}
# 2023-07-16 12:21:21,588 INFO sqlalchemy.engine.Engine COMMIT
# aggressive
# 2023-07-16 12:21:21,590 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,590 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,591 INFO sqlalchemy.engine.Engine [cached since 77.66s ago] {'word': 'cashmere', 'level': 3}
# 2023-07-16 12:21:21,591 INFO sqlalchemy.engine.Engine COMMIT
# cashmere
# 2023-07-16 12:21:21,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,593 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,593 INFO sqlalchemy.engine.Engine [cached since 77.66s ago] {'word': 'dubious', 'level': 3}
# 2023-07-16 12:21:21,594 INFO sqlalchemy.engine.Engine COMMIT
# dubious
# 2023-07-16 12:21:21,595 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,596 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,596 INFO sqlalchemy.engine.Engine [cached since 77.66s ago] {'word': 'hydroponics', 'level': 3}
# 2023-07-16 12:21:21,597 INFO sqlalchemy.engine.Engine COMMIT
# hydroponics
# 2023-07-16 12:21:21,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,600 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,601 INFO sqlalchemy.engine.Engine [cached since 77.67s ago] {'word': 'prospector', 'level': 3}
# 2023-07-16 12:21:21,602 INFO sqlalchemy.engine.Engine COMMIT
# prospector
# 2023-07-16 12:21:21,609 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,610 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,611 INFO sqlalchemy.engine.Engine [cached since 77.68s ago] {'word': 'allure', 'level': 3}
# 2023-07-16 12:21:21,613 INFO sqlalchemy.engine.Engine COMMIT
# allure
# 2023-07-16 12:21:21,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,616 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,616 INFO sqlalchemy.engine.Engine [cached since 77.68s ago] {'word': 'causeway', 'level': 3}
# 2023-07-16 12:21:21,617 INFO sqlalchemy.engine.Engine COMMIT
# causeway
# 2023-07-16 12:21:21,618 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,619 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,619 INFO sqlalchemy.engine.Engine [cached since 77.68s ago] {'word': 'dunnart', 'level': 3}
# 2023-07-16 12:21:21,620 INFO sqlalchemy.engine.Engine COMMIT
# dunnart
# 2023-07-16 12:21:21,621 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,622 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,622 INFO sqlalchemy.engine.Engine [cached since 77.69s ago] {'word': 'hysterical', 'level': 3}
# 2023-07-16 12:21:21,623 INFO sqlalchemy.engine.Engine COMMIT
# hysterical
# 2023-07-16 12:21:21,624 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,625 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,626 INFO sqlalchemy.engine.Engine [cached since 77.69s ago] {'word': 'pungent', 'level': 3}
# 2023-07-16 12:21:21,627 INFO sqlalchemy.engine.Engine COMMIT
# pungent
# 2023-07-16 12:21:21,629 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,629 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,629 INFO sqlalchemy.engine.Engine [cached since 77.69s ago] {'word': 'alphabet', 'level': 3}
# 2023-07-16 12:21:21,630 INFO sqlalchemy.engine.Engine COMMIT
# alphabet
# 2023-07-16 12:21:21,632 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,633 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,635 INFO sqlalchemy.engine.Engine [cached since 77.7s ago] {'word': 'cavalry', 'level': 3}
# 2023-07-16 12:21:21,636 INFO sqlalchemy.engine.Engine COMMIT
# cavalry
# 2023-07-16 12:21:21,638 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,638 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,639 INFO sqlalchemy.engine.Engine [cached since 77.7s ago] {'word': 'dynamic', 'level': 3}
# 2023-07-16 12:21:21,640 INFO sqlalchemy.engine.Engine COMMIT
# dynamic
# 2023-07-16 12:21:21,642 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,642 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,642 INFO sqlalchemy.engine.Engine [cached since 77.71s ago] {'word': 'imperative', 'level': 3}
# 2023-07-16 12:21:21,643 INFO sqlalchemy.engine.Engine COMMIT
# imperative
# 2023-07-16 12:21:21,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,645 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,645 INFO sqlalchemy.engine.Engine [cached since 77.71s ago] {'word': 'pyramid', 'level': 3}
# 2023-07-16 12:21:21,646 INFO sqlalchemy.engine.Engine COMMIT
# pyramid
# 2023-07-16 12:21:21,650 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,651 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,652 INFO sqlalchemy.engine.Engine [cached since 77.72s ago] {'word': 'alteration', 'level': 3}
# 2023-07-16 12:21:21,653 INFO sqlalchemy.engine.Engine COMMIT
# alteration
# 2023-07-16 12:21:21,659 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,668 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,668 INFO sqlalchemy.engine.Engine [cached since 77.73s ago] {'word': 'certificate', 'level': 3}
# 2023-07-16 12:21:21,674 INFO sqlalchemy.engine.Engine COMMIT
# certificate
# 2023-07-16 12:21:21,699 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,699 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,699 INFO sqlalchemy.engine.Engine [cached since 77.76s ago] {'word': 'eavesdrop', 'level': 3}
# 2023-07-16 12:21:21,701 INFO sqlalchemy.engine.Engine COMMIT
# eavesdrop
# 2023-07-16 12:21:21,702 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,703 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,703 INFO sqlalchemy.engine.Engine [cached since 77.77s ago] {'word': 'implicit', 'level': 3}
# 2023-07-16 12:21:21,709 INFO sqlalchemy.engine.Engine COMMIT
# implicit
# 2023-07-16 12:21:21,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,721 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,722 INFO sqlalchemy.engine.Engine [cached since 77.79s ago] {'word': 'questionable', 'level': 3}
# 2023-07-16 12:21:21,726 INFO sqlalchemy.engine.Engine COMMIT
# questionable
# 2023-07-16 12:21:21,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,728 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,729 INFO sqlalchemy.engine.Engine [cached since 77.79s ago] {'word': 'ancestor', 'level': 3}
# 2023-07-16 12:21:21,730 INFO sqlalchemy.engine.Engine COMMIT
# ancestor
# 2023-07-16 12:21:21,734 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,735 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,735 INFO sqlalchemy.engine.Engine [cached since 77.8s ago] {'word': 'collective', 'level': 3}
# 2023-07-16 12:21:21,737 INFO sqlalchemy.engine.Engine COMMIT
# collective
# 2023-07-16 12:21:21,742 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,742 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,742 INFO sqlalchemy.engine.Engine [cached since 77.81s ago] {'word': 'ebony', 'level': 3}
# 2023-07-16 12:21:21,743 INFO sqlalchemy.engine.Engine COMMIT
# ebony
# 2023-07-16 12:21:21,745 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,746 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,746 INFO sqlalchemy.engine.Engine [cached since 77.81s ago] {'word': 'imprudent', 'level': 3}
# 2023-07-16 12:21:21,747 INFO sqlalchemy.engine.Engine COMMIT
# imprudent
# 2023-07-16 12:21:21,748 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,748 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,749 INFO sqlalchemy.engine.Engine [cached since 77.81s ago] {'word': 'ricotta', 'level': 3}
# 2023-07-16 12:21:21,751 INFO sqlalchemy.engine.Engine COMMIT
# ricotta
# 2023-07-16 12:21:21,753 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,754 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,755 INFO sqlalchemy.engine.Engine [cached since 77.82s ago] {'word': 'angora', 'level': 3}
# 2023-07-16 12:21:21,758 INFO sqlalchemy.engine.Engine COMMIT
# angora
# 2023-07-16 12:21:21,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,760 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,761 INFO sqlalchemy.engine.Engine [cached since 77.83s ago] {'word': 'committee', 'level': 3}
# 2023-07-16 12:21:21,764 INFO sqlalchemy.engine.Engine COMMIT
# committee
# 2023-07-16 12:21:21,766 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,767 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,768 INFO sqlalchemy.engine.Engine [cached since 77.83s ago] {'word': 'eighteen', 'level': 3}
# 2023-07-16 12:21:21,769 INFO sqlalchemy.engine.Engine COMMIT
# eighteen
# 2023-07-16 12:21:21,772 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,772 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,773 INFO sqlalchemy.engine.Engine [cached since 77.84s ago] {'word': 'incongruous', 'level': 3}
# 2023-07-16 12:21:21,774 INFO sqlalchemy.engine.Engine COMMIT
# incongruous
# 2023-07-16 12:21:21,777 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,778 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,780 INFO sqlalchemy.engine.Engine [cached since 77.85s ago] {'word': 'salient', 'level': 3}
# 2023-07-16 12:21:21,785 INFO sqlalchemy.engine.Engine COMMIT
# salient
# 2023-07-16 12:21:21,792 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,793 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,795 INFO sqlalchemy.engine.Engine [cached since 77.86s ago] {'word': 'aniseed', 'level': 3}
# 2023-07-16 12:21:21,799 INFO sqlalchemy.engine.Engine COMMIT
# aniseed
# 2023-07-16 12:21:21,803 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,804 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,805 INFO sqlalchemy.engine.Engine [cached since 77.87s ago] {'word': 'competitive', 'level': 3}
# 2023-07-16 12:21:21,811 INFO sqlalchemy.engine.Engine COMMIT
# competitive
# 2023-07-16 12:21:21,814 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,814 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,815 INFO sqlalchemy.engine.Engine [cached since 77.88s ago] {'word': 'elusive', 'level': 3}
# 2023-07-16 12:21:21,815 INFO sqlalchemy.engine.Engine COMMIT
# elusive
# 2023-07-16 12:21:21,817 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,817 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,818 INFO sqlalchemy.engine.Engine [cached since 77.88s ago] {'word': 'inhumane', 'level': 3}
# 2023-07-16 12:21:21,818 INFO sqlalchemy.engine.Engine COMMIT
# inhumane
# 2023-07-16 12:21:21,823 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,826 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,827 INFO sqlalchemy.engine.Engine [cached since 77.89s ago] {'word': 'serpentine', 'level': 3}
# 2023-07-16 12:21:21,829 INFO sqlalchemy.engine.Engine COMMIT
# serpentine
# 2023-07-16 12:21:21,830 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,831 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,831 INFO sqlalchemy.engine.Engine [cached since 77.9s ago] {'word': 'appease', 'level': 3}
# 2023-07-16 12:21:21,832 INFO sqlalchemy.engine.Engine COMMIT
# appease
# 2023-07-16 12:21:21,833 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,834 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,834 INFO sqlalchemy.engine.Engine [cached since 77.9s ago] {'word': 'complaint', 'level': 3}
# 2023-07-16 12:21:21,835 INFO sqlalchemy.engine.Engine COMMIT
# complaint
# 2023-07-16 12:21:21,838 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,838 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,839 INFO sqlalchemy.engine.Engine [cached since 77.9s ago] {'word': 'embellish', 'level': 3}
# 2023-07-16 12:21:21,840 INFO sqlalchemy.engine.Engine COMMIT
# embellish
# 2023-07-16 12:21:21,842 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,843 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,843 INFO sqlalchemy.engine.Engine [cached since 77.91s ago] {'word': 'injunction', 'level': 3}
# 2023-07-16 12:21:21,844 INFO sqlalchemy.engine.Engine COMMIT
# injunction
# 2023-07-16 12:21:21,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,846 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,847 INFO sqlalchemy.engine.Engine [cached since 77.91s ago] {'word': 'silicone', 'level': 3}
# 2023-07-16 12:21:21,848 INFO sqlalchemy.engine.Engine COMMIT
# silicone
# 2023-07-16 12:21:21,851 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,851 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,852 INFO sqlalchemy.engine.Engine [cached since 77.92s ago] {'word': 'armament', 'level': 3}
# 2023-07-16 12:21:21,853 INFO sqlalchemy.engine.Engine COMMIT
# armament
# 2023-07-16 12:21:21,857 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,857 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,858 INFO sqlalchemy.engine.Engine [cached since 77.92s ago] {'word': 'compulsory', 'level': 3}
# 2023-07-16 12:21:21,862 INFO sqlalchemy.engine.Engine COMMIT
# compulsory
# 2023-07-16 12:21:21,867 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,870 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,876 INFO sqlalchemy.engine.Engine [cached since 77.94s ago] {'word': 'enterprise', 'level': 3}
# 2023-07-16 12:21:21,881 INFO sqlalchemy.engine.Engine COMMIT
# enterprise
# 2023-07-16 12:21:21,891 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,891 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,892 INFO sqlalchemy.engine.Engine [cached since 77.96s ago] {'word': 'innumerable', 'level': 3}
# 2023-07-16 12:21:21,892 INFO sqlalchemy.engine.Engine COMMIT
# innumerable
# 2023-07-16 12:21:21,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,895 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,895 INFO sqlalchemy.engine.Engine [cached since 77.96s ago] {'word': 'simulcast', 'level': 3}
# 2023-07-16 12:21:21,897 INFO sqlalchemy.engine.Engine COMMIT
# simulcast
# 2023-07-16 12:21:21,899 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,900 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,900 INFO sqlalchemy.engine.Engine [cached since 77.97s ago] {'word': 'attentive', 'level': 3}
# 2023-07-16 12:21:21,901 INFO sqlalchemy.engine.Engine COMMIT
# attentive
# 2023-07-16 12:21:21,904 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,906 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,907 INFO sqlalchemy.engine.Engine [cached since 77.97s ago] {'word': 'condiment', 'level': 3}
# 2023-07-16 12:21:21,910 INFO sqlalchemy.engine.Engine COMMIT
# condiment
# 2023-07-16 12:21:21,912 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,913 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,913 INFO sqlalchemy.engine.Engine [cached since 77.98s ago] {'word': 'exceed', 'level': 3}
# 2023-07-16 12:21:21,914 INFO sqlalchemy.engine.Engine COMMIT
# exceed
# 2023-07-16 12:21:21,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,917 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,917 INFO sqlalchemy.engine.Engine [cached since 77.98s ago] {'word': 'insignia', 'level': 3}
# 2023-07-16 12:21:21,918 INFO sqlalchemy.engine.Engine COMMIT
# insignia
# 2023-07-16 12:21:21,920 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,921 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,922 INFO sqlalchemy.engine.Engine [cached since 77.99s ago] {'word': 'souvenir', 'level': 3}
# 2023-07-16 12:21:21,923 INFO sqlalchemy.engine.Engine COMMIT
# souvenir
# 2023-07-16 12:21:21,926 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,927 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,927 INFO sqlalchemy.engine.Engine [cached since 77.99s ago] {'word': 'aversion', 'level': 3}
# 2023-07-16 12:21:21,928 INFO sqlalchemy.engine.Engine COMMIT
# aversion
# 2023-07-16 12:21:21,930 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,931 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,931 INFO sqlalchemy.engine.Engine [cached since 78s ago] {'word': 'conference', 'level': 3}
# 2023-07-16 12:21:21,933 INFO sqlalchemy.engine.Engine COMMIT
# conference
# 2023-07-16 12:21:21,937 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,938 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,940 INFO sqlalchemy.engine.Engine [cached since 78.01s ago] {'word': 'excitable', 'level': 3}
# 2023-07-16 12:21:21,941 INFO sqlalchemy.engine.Engine COMMIT
# excitable
# 2023-07-16 12:21:21,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,943 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,944 INFO sqlalchemy.engine.Engine [cached since 78.01s ago] {'word': 'insincere', 'level': 3}
# 2023-07-16 12:21:21,944 INFO sqlalchemy.engine.Engine COMMIT
# insincere
# 2023-07-16 12:21:21,946 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,947 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,947 INFO sqlalchemy.engine.Engine [cached since 78.01s ago] {'word': 'suite', 'level': 3}
# 2023-07-16 12:21:21,948 INFO sqlalchemy.engine.Engine COMMIT
# suite
# 2023-07-16 12:21:21,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,951 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,951 INFO sqlalchemy.engine.Engine [cached since 78.02s ago] {'word': 'avocado', 'level': 3}
# 2023-07-16 12:21:21,953 INFO sqlalchemy.engine.Engine COMMIT
# avocado
# 2023-07-16 12:21:21,954 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,955 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,955 INFO sqlalchemy.engine.Engine [cached since 78.02s ago] {'word': 'contraband', 'level': 3}
# 2023-07-16 12:21:21,957 INFO sqlalchemy.engine.Engine COMMIT
# contraband
# 2023-07-16 12:21:21,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,959 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,960 INFO sqlalchemy.engine.Engine [cached since 78.03s ago] {'word': 'executive', 'level': 3}
# 2023-07-16 12:21:21,961 INFO sqlalchemy.engine.Engine COMMIT
# executive
# 2023-07-16 12:21:21,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,963 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,963 INFO sqlalchemy.engine.Engine [cached since 78.03s ago] {'word': 'insurance', 'level': 3}
# 2023-07-16 12:21:21,964 INFO sqlalchemy.engine.Engine COMMIT
# insurance
# 2023-07-16 12:21:21,966 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,966 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,967 INFO sqlalchemy.engine.Engine [cached since 78.03s ago] {'word': 'superfluous', 'level': 3}
# 2023-07-16 12:21:21,968 INFO sqlalchemy.engine.Engine COMMIT
# superfluous
# 2023-07-16 12:21:21,971 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,971 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,972 INFO sqlalchemy.engine.Engine [cached since 78.04s ago] {'word': 'awesome', 'level': 3}
# 2023-07-16 12:21:21,973 INFO sqlalchemy.engine.Engine COMMIT
# awesome
# 2023-07-16 12:21:21,975 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,975 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,976 INFO sqlalchemy.engine.Engine [cached since 78.04s ago] {'word': 'courtesy', 'level': 3}
# 2023-07-16 12:21:21,977 INFO sqlalchemy.engine.Engine COMMIT
# courtesy
# 2023-07-16 12:21:21,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,979 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,980 INFO sqlalchemy.engine.Engine [cached since 78.05s ago] {'word': 'expedition', 'level': 3}
# 2023-07-16 12:21:21,982 INFO sqlalchemy.engine.Engine COMMIT
# expedition
# 2023-07-16 12:21:21,984 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,985 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,985 INFO sqlalchemy.engine.Engine [cached since 78.05s ago] {'word': 'integrate', 'level': 3}
# 2023-07-16 12:21:21,986 INFO sqlalchemy.engine.Engine COMMIT
# integrate
# 2023-07-16 12:21:21,988 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,988 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,988 INFO sqlalchemy.engine.Engine [cached since 78.05s ago] {'word': 'surrender', 'level': 3}
# 2023-07-16 12:21:21,990 INFO sqlalchemy.engine.Engine COMMIT
# surrender
# 2023-07-16 12:21:21,992 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,992 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,993 INFO sqlalchemy.engine.Engine [cached since 78.06s ago] {'word': 'barista', 'level': 3}
# 2023-07-16 12:21:21,994 INFO sqlalchemy.engine.Engine COMMIT
# barista
# 2023-07-16 12:21:21,995 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,995 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,996 INFO sqlalchemy.engine.Engine [cached since 78.06s ago] {'word': 'decipher', 'level': 3}
# 2023-07-16 12:21:21,997 INFO sqlalchemy.engine.Engine COMMIT
# decipher
# 2023-07-16 12:21:21,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:21,998 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:21,999 INFO sqlalchemy.engine.Engine [cached since 78.06s ago] {'word': 'fishmonger', 'level': 3}
# 2023-07-16 12:21:22,000 INFO sqlalchemy.engine.Engine COMMIT
# fishmonger
# 2023-07-16 12:21:22,002 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,002 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,002 INFO sqlalchemy.engine.Engine [cached since 78.07s ago] {'word': 'irregular', 'level': 3}
# 2023-07-16 12:21:22,004 INFO sqlalchemy.engine.Engine COMMIT
# irregular
# 2023-07-16 12:21:22,006 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,007 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,008 INFO sqlalchemy.engine.Engine [cached since 78.07s ago] {'word': 'tandoori', 'level': 3}
# 2023-07-16 12:21:22,010 INFO sqlalchemy.engine.Engine COMMIT
# tandoori
# 2023-07-16 12:21:22,018 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,018 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,019 INFO sqlalchemy.engine.Engine [cached since 78.08s ago] {'word': 'basmati', 'level': 3}
# 2023-07-16 12:21:22,020 INFO sqlalchemy.engine.Engine COMMIT
# basmati
# 2023-07-16 12:21:22,021 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,022 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,022 INFO sqlalchemy.engine.Engine [cached since 78.09s ago] {'word': 'delight', 'level': 3}
# 2023-07-16 12:21:22,023 INFO sqlalchemy.engine.Engine COMMIT
# delight
# 2023-07-16 12:21:22,025 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,025 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,026 INFO sqlalchemy.engine.Engine [cached since 78.09s ago] {'word': 'forensic', 'level': 3}
# 2023-07-16 12:21:22,027 INFO sqlalchemy.engine.Engine COMMIT
# forensic
# 2023-07-16 12:21:22,029 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,029 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,029 INFO sqlalchemy.engine.Engine [cached since 78.09s ago] {'word': 'luminous', 'level': 3}
# 2023-07-16 12:21:22,030 INFO sqlalchemy.engine.Engine COMMIT
# luminous
# 2023-07-16 12:21:22,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,066 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,067 INFO sqlalchemy.engine.Engine [cached since 78.13s ago] {'word': 'tangent', 'level': 3}
# 2023-07-16 12:21:22,069 INFO sqlalchemy.engine.Engine COMMIT
# tangent
# 2023-07-16 12:21:22,071 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,072 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,072 INFO sqlalchemy.engine.Engine [cached since 78.14s ago] {'word': 'bauble', 'level': 3}
# 2023-07-16 12:21:22,073 INFO sqlalchemy.engine.Engine COMMIT
# bauble
# 2023-07-16 12:21:22,075 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,078 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,080 INFO sqlalchemy.engine.Engine [cached since 78.15s ago] {'word': 'departure', 'level': 3}
# 2023-07-16 12:21:22,083 INFO sqlalchemy.engine.Engine COMMIT
# departure
# 2023-07-16 12:21:22,086 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,086 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,086 INFO sqlalchemy.engine.Engine [cached since 78.15s ago] {'word': 'forgery', 'level': 3}
# 2023-07-16 12:21:22,088 INFO sqlalchemy.engine.Engine COMMIT
# forgery
# 2023-07-16 12:21:22,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,090 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,090 INFO sqlalchemy.engine.Engine [cached since 78.16s ago] {'word': 'marmalade', 'level': 3}
# 2023-07-16 12:21:22,091 INFO sqlalchemy.engine.Engine COMMIT
# marmalade
# 2023-07-16 12:21:22,093 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,094 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,094 INFO sqlalchemy.engine.Engine [cached since 78.16s ago] {'word': 'tendency', 'level': 3}
# 2023-07-16 12:21:22,095 INFO sqlalchemy.engine.Engine COMMIT
# tendency
# 2023-07-16 12:21:22,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,098 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,098 INFO sqlalchemy.engine.Engine [cached since 78.16s ago] {'word': 'begrudge', 'level': 3}
# 2023-07-16 12:21:22,099 INFO sqlalchemy.engine.Engine COMMIT
# begrudge
# 2023-07-16 12:21:22,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,103 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,103 INFO sqlalchemy.engine.Engine [cached since 78.17s ago] {'word': 'dessert', 'level': 3}
# 2023-07-16 12:21:22,104 INFO sqlalchemy.engine.Engine COMMIT
# dessert
# 2023-07-16 12:21:22,105 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,106 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,106 INFO sqlalchemy.engine.Engine [cached since 78.17s ago] {'word': 'forthright', 'level': 3}
# 2023-07-16 12:21:22,107 INFO sqlalchemy.engine.Engine COMMIT
# forthright
# 2023-07-16 12:21:22,109 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,109 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,110 INFO sqlalchemy.engine.Engine [cached since 78.18s ago] {'word': 'merciless', 'level': 3}
# 2023-07-16 12:21:22,111 INFO sqlalchemy.engine.Engine COMMIT
# merciless
# 2023-07-16 12:21:22,113 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,113 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,114 INFO sqlalchemy.engine.Engine [cached since 78.18s ago] {'word': 'thermostat', 'level': 3}
# 2023-07-16 12:21:22,115 INFO sqlalchemy.engine.Engine COMMIT
# thermostat
# 2023-07-16 12:21:22,117 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,117 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,118 INFO sqlalchemy.engine.Engine [cached since 78.18s ago] {'word': 'beret', 'level': 3}
# 2023-07-16 12:21:22,119 INFO sqlalchemy.engine.Engine COMMIT
# beret
# 2023-07-16 12:21:22,120 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,121 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,121 INFO sqlalchemy.engine.Engine [cached since 78.19s ago] {'word': 'destitute', 'level': 3}
# 2023-07-16 12:21:22,122 INFO sqlalchemy.engine.Engine COMMIT
# destitute
# 2023-07-16 12:21:22,124 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,125 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,125 INFO sqlalchemy.engine.Engine [cached since 78.19s ago] {'word': 'fraternal', 'level': 3}
# 2023-07-16 12:21:22,127 INFO sqlalchemy.engine.Engine COMMIT
# fraternal
# 2023-07-16 12:21:22,130 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,131 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,133 INFO sqlalchemy.engine.Engine [cached since 78.2s ago] {'word': 'mischief', 'level': 3}
# 2023-07-16 12:21:22,134 INFO sqlalchemy.engine.Engine COMMIT
# mischief
# 2023-07-16 12:21:22,136 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,136 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,137 INFO sqlalchemy.engine.Engine [cached since 78.2s ago] {'word': 'thoughtful', 'level': 3}
# 2023-07-16 12:21:22,138 INFO sqlalchemy.engine.Engine COMMIT
# thoughtful
# 2023-07-16 12:21:22,141 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,141 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,142 INFO sqlalchemy.engine.Engine [cached since 78.21s ago] {'word': 'billabong', 'level': 3}
# 2023-07-16 12:21:22,143 INFO sqlalchemy.engine.Engine COMMIT
# billabong
# 2023-07-16 12:21:22,144 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,145 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,145 INFO sqlalchemy.engine.Engine [cached since 78.21s ago] {'word': 'detective', 'level': 3}
# 2023-07-16 12:21:22,146 INFO sqlalchemy.engine.Engine COMMIT
# detective
# 2023-07-16 12:21:22,148 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,149 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,149 INFO sqlalchemy.engine.Engine [cached since 78.21s ago] {'word': 'frenzied', 'level': 3}
# 2023-07-16 12:21:22,149 INFO sqlalchemy.engine.Engine COMMIT
# frenzied
# 2023-07-16 12:21:22,151 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,152 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,153 INFO sqlalchemy.engine.Engine [cached since 78.22s ago] {'word': 'monotreme', 'level': 3}
# 2023-07-16 12:21:22,154 INFO sqlalchemy.engine.Engine COMMIT
# monotreme
# 2023-07-16 12:21:22,158 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,158 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,159 INFO sqlalchemy.engine.Engine [cached since 78.22s ago] {'word': 'tiresome', 'level': 3}
# 2023-07-16 12:21:22,160 INFO sqlalchemy.engine.Engine COMMIT
# tiresome
# 2023-07-16 12:21:22,161 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,162 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,162 INFO sqlalchemy.engine.Engine [cached since 78.23s ago] {'word': 'blithely', 'level': 3}
# 2023-07-16 12:21:22,163 INFO sqlalchemy.engine.Engine COMMIT
# blithely
# 2023-07-16 12:21:22,164 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,164 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,165 INFO sqlalchemy.engine.Engine [cached since 78.23s ago] {'word': 'dictionary', 'level': 3}
# 2023-07-16 12:21:22,166 INFO sqlalchemy.engine.Engine COMMIT
# dictionary
# 2023-07-16 12:21:22,171 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,172 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,172 INFO sqlalchemy.engine.Engine [cached since 78.24s ago] {'word': 'ganache', 'level': 3}
# 2023-07-16 12:21:22,176 INFO sqlalchemy.engine.Engine COMMIT
# ganache
# 2023-07-16 12:21:22,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,180 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,181 INFO sqlalchemy.engine.Engine [cached since 78.25s ago] {'word': 'monumental', 'level': 3}
# 2023-07-16 12:21:22,183 INFO sqlalchemy.engine.Engine COMMIT
# monumental
# 2023-07-16 12:21:22,186 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,187 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,188 INFO sqlalchemy.engine.Engine [cached since 78.25s ago] {'word': 'underlie', 'level': 3}
# 2023-07-16 12:21:22,190 INFO sqlalchemy.engine.Engine COMMIT
# underlie
# 2023-07-16 12:21:22,192 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,193 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,193 INFO sqlalchemy.engine.Engine [cached since 78.26s ago] {'word': 'blockade', 'level': 3}
# 2023-07-16 12:21:22,195 INFO sqlalchemy.engine.Engine COMMIT
# blockade
# 2023-07-16 12:21:22,196 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,197 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,197 INFO sqlalchemy.engine.Engine [cached since 78.26s ago] {'word': 'diffident', 'level': 3}
# 2023-07-16 12:21:22,198 INFO sqlalchemy.engine.Engine COMMIT
# diffident
# 2023-07-16 12:21:22,200 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,201 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,202 INFO sqlalchemy.engine.Engine [cached since 78.27s ago] {'word': 'gardenia', 'level': 3}
# 2023-07-16 12:21:22,203 INFO sqlalchemy.engine.Engine COMMIT
# gardenia
# 2023-07-16 12:21:22,206 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,207 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,207 INFO sqlalchemy.engine.Engine [cached since 78.27s ago] {'word': 'mosquito', 'level': 3}
# 2023-07-16 12:21:22,208 INFO sqlalchemy.engine.Engine COMMIT
# mosquito
# 2023-07-16 12:21:22,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,211 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,211 INFO sqlalchemy.engine.Engine [cached since 78.28s ago] {'word': 'urgency', 'level': 3}
# 2023-07-16 12:21:22,212 INFO sqlalchemy.engine.Engine COMMIT
# urgency
# 2023-07-16 12:21:22,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,215 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,216 INFO sqlalchemy.engine.Engine [cached since 78.28s ago] {'word': 'blustery', 'level': 3}
# 2023-07-16 12:21:22,220 INFO sqlalchemy.engine.Engine COMMIT
# blustery
# 2023-07-16 12:21:22,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,226 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,227 INFO sqlalchemy.engine.Engine [cached since 78.29s ago] {'word': 'diploma', 'level': 3}
# 2023-07-16 12:21:22,228 INFO sqlalchemy.engine.Engine COMMIT
# diploma
# 2023-07-16 12:21:22,231 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,231 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,232 INFO sqlalchemy.engine.Engine [cached since 78.3s ago] {'word': 'garrulous', 'level': 3}
# 2023-07-16 12:21:22,233 INFO sqlalchemy.engine.Engine COMMIT
# garrulous
# 2023-07-16 12:21:22,236 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-07-16 12:21:22,236 INFO sqlalchemy.engine.Engine INSERT INTO word (word, level) VALUES (%(word)s, %(level)s) RETURNING word.word
# 2023-07-16 12:21:22,238 INFO sqlalchemy.engine.Engine [cached since 78.3s ago] {'word': 'negligent', 'level': 3}
# 2023-07-16 12:21:22,239 INFO sqlalchemy.engine.Engine COMMIT
# negligent
